# %% [markdown]
# ## Studying the bell curve effect.
#
# We wish to investigate if we observe the bell shape, with respect to mem loss, and the difference between mem and gen loss.

# %%
import matplotlib.pyplot as plt
import numpy as np

import jax
import jax.numpy as jnp
from jax import random

# diffusionlab imports
from diffusionlab.dynamics import VariancePreservingProcess
from diffusionlab.losses import DiffusionLoss
from diffusionlab.vector_fields import VectorFieldType

# repo imports
from investigating_diffusion_loss import AmbientDiffusionLoss
from src.diffusion_mem_gen.models.gmm import (
    IsoHomGMMInitStrategy,
    iso_hom_gmm_create_initialization_parameters,
    IsoHomGMMSharedParametersEstimator,
)
from src.diffusion_mem_gen.utils.factories import compute_loss_factory

# Set random key
key = random.PRNGKey(0)

# %%
# Diffusion process
diffusion_process = VariancePreservingProcess()

# Dimension and training samples
laboratory_d = 100  # data dimension
laboratory_N = 200  # number of training samples
laboratory_K = 12 # number of components in the GMM
laboratory_M = 100  # number of components for partially memorizing denoiser

u_means_variance = 30 ** (1/2)  # order 1, controls the variance of the means of the true distribution
sample_variance = 1 

# Time grid for evaluation
t_val_array = jnp.linspace(0.01, 0.99, 26)

# %%
# Generate ground-truth GMM and training data
key, sk = random.split(key)
true_means = random.normal(sk, (laboratory_K, laboratory_d)) * u_means_variance
equal_weighted_prior = jnp.array([1/laboratory_K for _ in range(laboratory_K)])

# Sample training set from the true GMM
key, sk = random.split(key)
comp_ids = random.choice(sk, laboratory_K, shape=(laboratory_N,), p=equal_weighted_prior)
key, sk = random.split(key)
X_train = true_means[comp_ids] + jnp.sqrt(sample_variance) * random.normal(sk, (laboratory_N, laboratory_d))

# %%
# Check that the min distance between the means is order d, and the max modulus is order d.

from scipy.spatial.distance import pdist
import numpy as np

# Calculate all pairwise distances between the means
pairwise_dists = pdist(true_means)
min_dist = np.min(pairwise_dists)

# Calculate the maximum modulus (maximum Euclidean norm from origin)
max_modulus = np.max(np.linalg.norm(true_means, axis=1))

print(f"Minimum distance between means: {min_dist:.3f} (should be ~O(d) == {laboratory_d})")
print(f"Maximum modulus of any mean: {max_modulus:.3f} (should be ~O(d) == {laboratory_d})")
# Out:
# Minimum distance between means: 69.284 (should be ~O(d) == 100)
# Maximum modulus of any mean: 63.214 (should be ~O(d) == 100)

# %%
# Build MEM denoiser (uses training points as memorised means)
key, sk = random.split(key)
context = {
    "X_train": X_train,
    "init_var_scale": 1e-10,
    "init_means_noise_var": 0.0,
}
means_mem, var_mem, priors_mem = iso_hom_gmm_create_initialization_parameters(
    sk, IsoHomGMMInitStrategy.PMEM, laboratory_d, laboratory_N, context
)
mem_model = IsoHomGMMSharedParametersEstimator(
    dim=laboratory_d,
    num_components=laboratory_N,
    vf_type=VectorFieldType.X0,
    diffusion_process=diffusion_process,
    init_means=means_mem,
    init_var=var_mem,
    priors=priors_mem,
)

# Build Partially Memorising denoiser (uses M < N training points as memorised means)
key, sk = random.split(key)
context_pmem = {
    "X_train": X_train,
    "init_var_scale": 1e-6,
    "init_means_noise_var": 0.0,
}
means_pmem, var_pmem, priors_pmem = iso_hom_gmm_create_initialization_parameters(
    sk, IsoHomGMMInitStrategy.PMEM, laboratory_d, laboratory_M, context_pmem
)
pmem_model = IsoHomGMMSharedParametersEstimator(
    dim=laboratory_d,
    num_components=laboratory_M,
    vf_type=VectorFieldType.X0,
    diffusion_process=diffusion_process,
    init_means=means_pmem,
    init_var=var_pmem,
    priors=priors_pmem,
)

# Build Generalising denoiser
generalising_model = IsoHomGMMSharedParametersEstimator(
    dim=laboratory_d,
    num_components=laboratory_K,
    vf_type=VectorFieldType.X0,
    diffusion_process=diffusion_process,
    init_means=true_means,
    init_var=jnp.asarray(sample_variance),
    priors=equal_weighted_prior,
)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8064\3922115705.py:11: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   mem_model = IsoHomGMMSharedParametersEstimator(
# C:\Users\chris\AppData\Local\Temp\ipykernel_8064\3922115705.py:31: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   pmem_model = IsoHomGMMSharedParametersEstimator(
# C:\Users\chris\AppData\Local\Temp\ipykernel_8064\3922115705.py:42: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   generalising_model = IsoHomGMMSharedParametersEstimator(

# %%
# Create standard loss object once (reused for all computations)
standard_loss_obj = DiffusionLoss(
    diffusion_process, 
    vector_field_type=VectorFieldType.X0, 
    num_noise_draws_per_sample=1
)

def L_N_t(key, model_callable, t_val_array, t_n_value, X_0_dataset, X_t_n_dataset, lambda_fn):
    """
    Compute the total loss L_N_t for a given model.
    
    This function computes the loss by splitting the time array into:
    - Standard denoising: t <= t_n
    - Ambient denoising: t > t_n
    
    Optimizations:
    - Reuses the standard loss object
    - Uses efficient JAX operations
    - The compute_loss functions from compute_loss_factory already use JAX internally
      and will benefit from JAX's automatic optimization
    
    Returns the total loss.
    """
    # Create ambient loss object for this t_n_value
    ambient_loss_obj = AmbientDiffusionLoss(
        diffusion_process, 
        num_noise_draws_per_sample=1, 
        t_n=t_n_value
    )
    
    # Split time array into standard and ambient denoising regions
    less_than_n_mask = t_val_array <= t_n_value
    greater_than_n_mask = ~less_than_n_mask
    
    standard_denoising_t_values = t_val_array[less_than_n_mask]
    ambient_denoising_t_values = t_val_array[greater_than_n_mask]
    
    total_loss = 0.0
    
    # Compute standard denoising losses (t <= t_n)
    if len(standard_denoising_t_values) > 0:
        keys = random.split(key, len(standard_denoising_t_values))
        standard_losses = []
        for k, t in zip(keys, standard_denoising_t_values):
            compute_loss = compute_loss_factory(standard_loss_obj, t)
            loss_val = compute_loss(k, model_callable, X_0_dataset) / X_0_dataset.shape[0]
            standard_losses.append(lambda_fn(t) * loss_val)
        total_loss +=  t_n_value * jnp.mean(jnp.array(standard_losses))
    
    # Compute ambient denoising losses (t > t_n)
    if len(ambient_denoising_t_values) > 0:
        keys = random.split(key, len(ambient_denoising_t_values))
        ambient_losses = []
        for k, t in zip(keys, ambient_denoising_t_values):
            compute_loss = compute_loss_factory(ambient_loss_obj, t)
            loss_val = compute_loss(k, model_callable, X_t_n_dataset) / X_t_n_dataset.shape[0]
            ambient_losses.append(lambda_fn(t) * loss_val)
        total_loss += (1-t_n_value) * jnp.mean(jnp.array(ambient_losses))
    
    return total_loss

# %%
# Lambda function (weight function) - uniform weighting
lambda_fn = lambda t: 1.0

# Range of t_n values to investigate
t_n_values = jnp.linspace(0.01, 0.99, 17)  # 17 values from 0.1 to 0.9

# Pre-generate X_t_n datasets for each t_n value
batch_diffusion_forward = jax.vmap(
    diffusion_process.forward, in_axes=(0, None, 0)
)

X_t_n_datasets = {}
for t_n in t_n_values:
    key, subk = random.split(key)
    X_t_n_eps = random.normal(subk, X_train.shape)
    X_t_n_datasets[float(t_n)] = batch_diffusion_forward(X_train, t_n, X_t_n_eps)

# %%
# Compute losses for memorising, partially memorising and generalising models across different t_n values
mem_losses = []
pmem_losses = []
gen_losses = []

print("Computing losses...")
for i, t_n in enumerate(t_n_values):
    t_n_float = float(t_n)
    X_t_n_dataset = X_t_n_datasets[t_n_float]
    
    # Compute fully memorising model loss
    key, subk = random.split(key)
    mem_loss = L_N_t(
        subk, mem_model, t_val_array, t_n, X_train, X_t_n_dataset, lambda_fn
    )
    mem_losses.append(float(mem_loss))
    
    # Compute partially memorising model loss
    key, subk = random.split(key)
    pmem_loss = L_N_t(
        subk, pmem_model, t_val_array, t_n, X_train, X_t_n_dataset, lambda_fn
    )
    pmem_losses.append(float(pmem_loss))
    
    # Compute generalising model loss
    key, subk = random.split(key)
    gen_loss = L_N_t(
        subk, generalising_model, t_val_array, t_n, X_train, X_t_n_dataset, lambda_fn
    )
    gen_losses.append(float(gen_loss))
    
    if (i + 1) % 5 == 0:
        print(f"Completed {i + 1}/{len(t_n_values)} t_n values")

mem_losses = jnp.array(mem_losses)
pmem_losses = jnp.array(pmem_losses)
gen_losses = jnp.array(gen_losses)
loss_difference = pmem_losses - gen_losses
# Out:
# Computing losses...
# Completed 5/17 t_n values
# Completed 10/17 t_n values
# Completed 15/17 t_n values

# %%
# Plot 1: Total loss L_N_t of partially memorising denoiser vs t_n
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

ax1 = axes[0]
ax1.plot(t_n_values, pmem_losses, 'o-', linewidth=2, markersize=6, color='blue', label='Partially Memorising Model')
ax1.set_xlabel('$t_n$', fontsize=12)
ax1.set_ylabel('Total Loss $L_N^t$', fontsize=12)
ax1.set_title('Total Loss of Partially Memorising Denoiser vs $t_n$', fontsize=13)
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=10)

ax2 = axes[1]
ax2.plot(t_n_values, loss_difference, 's-', linewidth=2, markersize=6, color='red', label='PMEM Loss - Gen Loss')
ax2.axhline(y=0, color='black', linestyle='--', linewidth=1, alpha=0.5)
ax2.set_xlabel('$t_n$', fontsize=12)
ax2.set_ylabel('Loss Difference', fontsize=12)
ax2.set_title('Difference Between PMEM and Gen Loss vs $t_n$', fontsize=13)
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Combined plot showing memorising, partially memorising and generalising losses (professional styling for conference paper)
import seaborn as sns
from matplotlib import rcParams

# Set seaborn style for professional appearance
sns.set_style("whitegrid")
sns.set_palette("deep")
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman']
rcParams['font.size'] = 10
rcParams['axes.labelsize'] = 10
rcParams['axes.titlesize'] = 11
rcParams['xtick.labelsize'] = 9
rcParams['ytick.labelsize'] = 9
rcParams['legend.fontsize'] = 9
rcParams['figure.dpi'] = 300

fig, ax = plt.subplots(1, 1, figsize=(3.5, 2.8))  # Compact size for conference paper

ax.plot(t_n_values, mem_losses, '-', linewidth=1.5, markersize=4, color='#1B998B', label=r'$\mathbf{x}_{\text{mem}}$', marker='^', markevery=2)
ax.plot(t_n_values, pmem_losses, '-', linewidth=1.5, markersize=4, color='#2E86AB', label=r'$\mathbf{x}_{\text{pmem, 100}}$', marker='o', markevery=2)
ax.plot(t_n_values, gen_losses, '--', linewidth=1.5, markersize=4, color='#A23B72', label=r'$\mathbf{x}_{\text{gen}}$', marker='s', markevery=2)
ax.set_xlabel('$t_n$', fontsize=10)
ax.set_ylabel('Total Loss $L_N^t$', fontsize=10)
ax.set_title('Loss Comparison Across Denoiser Types', fontsize=11, pad=8)
ax.grid(True, alpha=0.3, linewidth=0.5)
ax.legend(frameon=True, fancybox=False, edgecolor='black', framealpha=0.9, loc='best')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

print(f"\nSummary Statistics:")
print(f"Mem loss range: [{mem_losses.min():.4f}, {mem_losses.max():.4f}]")
print(f"PMEM loss range: [{pmem_losses.min():.4f}, {pmem_losses.max():.4f}]")
print(f"Gen loss range: [{gen_losses.min():.4f}, {gen_losses.max():.4f}]")
print(f"Loss difference range: [{loss_difference.min():.4f}, {loss_difference.max():.4f}]")
# Out:
# Summary Statistics:
# Mem loss range: [0.0174, 0.0583]
# PMEM loss range: [0.3210, 0.4168]
# Gen loss range: [0.1262, 0.1717]
# Loss difference range: [0.1747, 0.2595]

# %%
# Function to compute loss at a specific (t, t_n) pair
def loss_at_t_tn(key, model_callable, t_val, t_n_value, X_0_dataset, X_t_n_dataset, lambda_fn):
    """
    Compute the loss contribution at a specific time t for a given t_n.
    
    Returns the weighted loss at time t.
    """
    if t_val <= t_n_value:
        # Standard denoising: use X_0_dataset
        compute_loss = compute_loss_factory(standard_loss_obj, t_val)
        loss_val = t_n_value * compute_loss(key, model_callable, X_0_dataset) / X_0_dataset.shape[0]
    else:
        # Ambient denoising: use X_t_n_dataset
        ambient_loss_obj = AmbientDiffusionLoss(
            diffusion_process, 
            num_noise_draws_per_sample=1, 
            t_n=t_n_value
        )
        compute_loss = compute_loss_factory(ambient_loss_obj, t_val)
        loss_val = (1 - t_n_value) * compute_loss(key, model_callable, X_t_n_dataset) / X_t_n_dataset.shape[0]
    
    return  lambda_fn(t_val) * loss_val

# Compute 3D loss data for both models
print("Computing 3D loss data...")
pmem_loss_3d = np.zeros((len(t_val_array), len(t_n_values)))
gen_loss_3d = np.zeros((len(t_val_array), len(t_n_values)))

for i, t_val in enumerate(t_val_array):
    for j, t_n in enumerate(t_n_values):
        t_n_float = float(t_n)
        X_t_n_dataset = X_t_n_datasets[t_n_float]
        
        # Compute partially memorising model loss at (t, t_n)
        key, subk = random.split(key)
        pmem_loss_3d[i, j] = float(loss_at_t_tn(
            subk, pmem_model, t_val, t_n, X_train, X_t_n_dataset, lambda_fn
        ))
        
        # Compute generalising model loss at (t, t_n)
        key, subk = random.split(key)
        gen_loss_3d[i, j] = float(loss_at_t_tn(
            subk, generalising_model, t_val, t_n, X_train, X_t_n_dataset, lambda_fn
        ))
    
    if (i + 1) % 5 == 0:
        print(f"Completed {i + 1}/{len(t_val_array)} t values")

print("3D loss computation complete!")
# Out:
# Computing 3D loss data...
# Completed 5/26 t values
# Completed 10/26 t values
# Completed 15/26 t values
# Completed 20/26 t values
# Completed 25/26 t values
# 3D loss computation complete!

# %%
# Create 3D plots for both denoisers (professional styling for conference paper)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.colors as mcolors

# Create meshgrid for plotting
T_mesh, T_n_mesh = np.meshgrid(np.array(t_val_array), np.array(t_n_values), indexing='ij')

# Set up professional styling for 3D plots
rcParams['font.size'] = 9
rcParams['axes.labelsize'] = 9
rcParams['xtick.labelsize'] = 8
rcParams['ytick.labelsize'] = 8
# Note: z-axis tick labelsize is set directly via tick_params below

# Create figure with two subplots side by side - compact for conference paper
fig = plt.figure(figsize=(6.5, 3.0))  # Compact size for conference paper

# Set the view so that (0,0) is closest to the viewer: azim=-135 (or 225) instead of 45
elev_angle = 25
azim_angle = -135

# Use viridis colormap for both plots and compute shared vmin/vmax
viridis_cmap = cm.get_cmap('viridis')
vmin = min(pmem_loss_3d.min(), gen_loss_3d.min())
vmax = max(pmem_loss_3d.max(), gen_loss_3d.max())

# Plot 1: Partially Memorising denoiser
ax1 = fig.add_subplot(121, projection='3d')
# Main surface, strong colours
surf1 = ax1.plot_surface(
    T_mesh, T_n_mesh, pmem_loss_3d,
    cmap=viridis_cmap,
    vmin=vmin,
    vmax=vmax,
    alpha=0.8,
    linewidth=0,
    antialiased=True,
    shade=True,
    edgecolor='none'
)
# Overlay mesh lines for interpretability
mesh1 = ax1.plot_wireframe(
    T_mesh, T_n_mesh, pmem_loss_3d,
    color='k',  # black mesh lines
    linewidth=0.3,
    alpha=1,
    rstride=max(1, T_mesh.shape[0] // 30),
    cstride=max(1, T_mesh.shape[1] // 30)
)

ax1.set_xlabel('$t$', fontsize=9, labelpad=3)
ax1.set_ylabel('$t_n$', fontsize=9, labelpad=3)
ax1.set_title(r'$\mathbf{x}_{\text{pmem, 100}}$', fontsize=10, pad=2, fontweight='normal')
ax1.view_init(elev=elev_angle, azim=azim_angle)
ax1.tick_params(axis='x', pad=-3, labelsize=7)
ax1.tick_params(axis='y', pad=-3, labelsize=7)
ax1.tick_params(axis='z', pad=-3, labelsize=7)

# Plot 2: Generalising denoiser
ax2 = fig.add_subplot(122, projection='3d')
# Main surface, strong colours
surf2 = ax2.plot_surface(
    T_mesh, T_n_mesh, gen_loss_3d,
    cmap=viridis_cmap,
    vmin=vmin,
    vmax=vmax,
    alpha=0.8,
    linewidth=0,
    antialiased=True,
    shade=True,
    edgecolor='none'
)
# Overlay mesh lines for interpretability
mesh2 = ax2.plot_wireframe(
    T_mesh, T_n_mesh, gen_loss_3d,
    color='k',  # black mesh lines
    linewidth=0.3,
    alpha=1,
    rstride=max(1, T_mesh.shape[0] // 30),
    cstride=max(1, T_mesh.shape[1] // 30)
)

ax2.set_xlabel('$t$', fontsize=9, labelpad=3)
ax2.set_ylabel('$t_n$', fontsize=9, labelpad=3)
ax2.set_zlabel(r'$\mathcal{L}^{\mathrm{Alg1}}_{N,\, t,\, t_n}$', fontsize=10, labelpad=2)
ax2.set_title(r'$\mathbf{x}_{\text{gen}}$', fontsize=10, pad=2, fontweight='normal')
ax2.view_init(elev=elev_angle, azim=azim_angle)
ax2.tick_params(axis='x', pad=-3, labelsize=7)
ax2.tick_params(axis='y', pad=-3, labelsize=7)
ax2.tick_params(axis='z', pad=-3, labelsize=7)

# Remove colorbar (do not add any colorbar)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8064\4223627594.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis_cmap = cm.get_cmap('viridis')

# %%
# Plot the difference between pmem and gen loss surfaces (xpmem - xgen)
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.colors as mcolors

# Create meshgrid for plotting
T_mesh, T_n_mesh = np.meshgrid(np.array(t_val_array), np.array(t_n_values), indexing='ij')

# Calculate the difference surface: pmem - gen
diff_loss_3d = pmem_loss_3d - gen_loss_3d

# Set up professional styling for 3D plot
rcParams['font.size'] = 9
rcParams['axes.labelsize'] = 9
rcParams['xtick.labelsize'] = 8
rcParams['ytick.labelsize'] = 8

# Allow user to choose the 3D view orientation
elev_angle = 25  # Set your preferred elevation angle here
azim_angle = 45  # Set your preferred azimuth angle here

# Use viridis colormap as in previous figures
viridis_cmap = cm.get_cmap('viridis')
vmin = diff_loss_3d.min()
vmax = diff_loss_3d.max()

# Create figure - single compact plot for conference paper
fig = plt.figure(figsize=(3.5, 2.8))  # Slightly wider for balanced single plot

ax = fig.add_subplot(111, projection='3d')
# Main surface: xpmem - xgen
surf = ax.plot_surface(
    T_mesh, T_n_mesh, diff_loss_3d,
    cmap=viridis_cmap,
    vmin=vmin,
    vmax=vmax,
    alpha=1,
    linewidth=0,
    antialiased=True,
    shade=True,
    edgecolor='none'
)
# Overlay mesh lines for interpretability
mesh = ax.plot_wireframe(
    T_mesh, T_n_mesh, diff_loss_3d,
    color='k',  # black mesh lines
    linewidth=0.3,
    alpha=0.9,
    rstride=max(1, T_mesh.shape[0] // 30),
    cstride=max(1, T_mesh.shape[1] // 30)
)

ax.set_xlabel('$t$', fontsize=9, labelpad=-3)
ax.set_ylabel('$t_n$', fontsize=9, labelpad=-3)
ax.set_zlabel(r'$(\mathcal{L}^{\mathrm{Alg1}}_{N,\, t,\, t_n})_{\rm pmem} - (\mathcal{L}^{\mathrm{Alg1}}_{N,\, t,\, t_n})_{\rm gen}$', fontsize=10, labelpad=2)
ax.set_title(r'$\mathcal{L}^{\mathrm{Alg1}}_{N,\, t,\, t_n}(\mathbf{x}_{\text{pmem, 100}}) - \mathcal{L}^{\mathrm{Alg1}}_{N,\, t,\, t_n}(\mathbf{x}_{\text{gen}})$', fontsize=10, pad=-5, fontweight='normal')
ax.view_init(elev=elev_angle, azim=azim_angle)
ax.tick_params(axis='x', pad=-3, labelsize=7)
ax.tick_params(axis='y', pad=-3, labelsize=7)
ax.tick_params(axis='z', pad=-3, labelsize=7)

# Remove colorbar (do not add any colorbar)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8064\1727516872.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   viridis_cmap = cm.get_cmap('viridis')
